# %% [markdown]
# # CarRacing-v0

# %%
import numpy as np
import os
import json
import tensorflow as tf
import random
from vae.vae import CVAE
from controller import make_controller
from env import make_env
from utils import PARSER
args = PARSER.parse_args(['--config_path', 'configs/carracing.config'])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-82be43480625> in <module>
#       5 import random
#       6 from vae.vae import CVAE
# ----> 7 from controller import make_controller
#       8 from env import make_env
#       9 from utils import PARSER
#
# ~/world-models-runthrough/WorldModels/controller.py in <module>
#       5 import sys
#       6
# ----> 7 from env import make_env
#       8 import time
#       9
#
# ~/world-models-runthrough/WorldModels/env.py in <module>
#      29
#      30 from vae.vae import CVAE
# ---> 31 from rnn.rnn import MDNRNN, rnn_next_state, rnn_init_state
#      32 class CarRacingMDNRNN(CarRacingWrapper):
#      33   def __init__(self, args, load_model=True, full_episode=False, with_obs=False):
#
# ~/world-models-runthrough/WorldModels/rnn/rnn.py in <module>
#       3 import json
#       4 import tensorflow as tf
# ----> 5 from tensorflow_probability import distributions as tfd
#       6 import tensorflow_probability as tfp
#       7
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_probability/__init__.py in <module>
#      74
#      75 # from tensorflow_probability.google import staging  # DisableOnExport
# ---> 76 from tensorflow_probability.python import *  # pylint: disable=wildcard-import
#      77 from tensorflow_probability.python.version import __version__
#      78 # pylint: enable=g-import-not-at-top
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_probability/python/__init__.py in <module>
#      22 from tensorflow_probability.python import debugging
#      23 from tensorflow_probability.python import distributions
# ---> 24 from tensorflow_probability.python import experimental
#      25 from tensorflow_probability.python import glm
#      26 from tensorflow_probability.python import layers
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_probability/python/experimental/__init__.py in <module>
#      32 from __future__ import print_function
#      33
# ---> 34 from tensorflow_probability.python.experimental import auto_batching
#      35 from tensorflow_probability.python.experimental import edward2
#      36 from tensorflow_probability.python.experimental import linalg
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_probability/python/experimental/auto_batching/__init__.py in <module>
#      22 from tensorflow_probability.python.experimental.auto_batching import allocation_strategy
#      23 from tensorflow_probability.python.experimental.auto_batching import dsl
# ---> 24 from tensorflow_probability.python.experimental.auto_batching import frontend
#      25 from tensorflow_probability.python.experimental.auto_batching import instructions
#      26 from tensorflow_probability.python.experimental.auto_batching import liveness
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_probability/python/experimental/auto_batching/frontend.py in <module>
#      43 from tensorflow.python.autograph.converters import return_statements
#      44 from tensorflow.python.autograph.core import converter
# ---> 45 from tensorflow.python.autograph.core import naming
#      46 from tensorflow.python.autograph.pyct import anno
#      47 from tensorflow.python.autograph.pyct import inspect_utils
#
# ImportError: cannot import name 'naming' from 'tensorflow.python.autograph.core' (/home/ubuntu/anaconda3/lib/python3.7/site-packages/tensorflow/python/autograph/core/__init__.py)

# %%
import matplotlib.pyplot as plt
import matplotlib.animation
# %matplotlib inline
np.set_printoptions(precision=4, edgeitems=6, linewidth=100, suppress=True)

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="-1" # disable GPU

DATA_DIR = "results/{}/{}/record".format(args.exp_name, args.env_name)
model_path_name = "results/{}/{}/tf_vae".format(args.exp_name, args.env_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-c0a6dcd41bf1> in <module>
#       1 os.environ["CUDA_VISIBLE_DEVICES"]="-1" # disable GPU
#       2
# ----> 3 DATA_DIR = "results/{}/{}/record".format(args.exp_name, args.env_name)
#       4 model_path_name = "results/{}/{}/tf_vae".format(args.exp_name, args.env_name)
#
# NameError: name 'args' is not defined

# %%
filelist = os.listdir(DATA_DIR)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-c9beb738daec> in <module>
# ----> 1 filelist = os.listdir(DATA_DIR)
#
# NameError: name 'DATA_DIR' is not defined

# %%
obs = np.load(os.path.join(DATA_DIR, random.choice(filelist)))["obs"]
obs = obs.astype(np.float32)/255.0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-d9cd8ffb1366> in <module>
# ----> 1 obs = np.load(os.path.join(DATA_DIR, random.choice(filelist)))["obs"]
#       2 obs = obs.astype(np.float32)/255.0
#
# NameError: name 'DATA_DIR' is not defined

# %%
obs.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-5136a989c5e6> in <module>
# ----> 1 obs.shape
#
# NameError: name 'obs' is not defined

# %%
frame = random.choice(obs).reshape(1, 64, 64, 3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-100ed8c27385> in <module>
# ----> 1 frame = random.choice(obs).reshape(1, 64, 64, 3)
#
# NameError: name 'obs' is not defined

# %%
vae = CVAE(args)

vae.set_weights(tf.keras.models.load_model(model_path_name, compile=False).get_weights())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-23d598c2f6ca> in <module>
# ----> 1 vae = CVAE(args)
#       2
#       3 vae.set_weights(tf.keras.models.load_model(model_path_name, compile=False).get_weights())
#
# NameError: name 'args' is not defined

# %%
# %matplotlib inline
# show recorded frame that will be fed into the input of VAE
plt.imshow(frame[0])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-13ea42954122> in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
#       2 # show recorded frame that will be fed into the input of VAE
# ----> 3 plt.imshow(frame[0])
#       4 plt.show()
#
# NameError: name 'frame' is not defined

# %%
batch_z = vae.encode(frame)
print(batch_z[0]) # print out sampled z
reconstruct = vae.decode(batch_z)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-8f192dbf5d71> in <module>
# ----> 1 batch_z = vae.encode(frame)
#       2 print(batch_z[0]) # print out sampled z
#       3 reconstruct = vae.decode(batch_z)
#
# NameError: name 'vae' is not defined

# %%
# %matplotlib inline
# show reconstruction
plt.imshow(reconstruct[0])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-f6a154b21a37> in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
#       2 # show reconstruction
# ----> 3 plt.imshow(reconstruct[0])
#       4 plt.show()
#
# NameError: name 'reconstruct' is not defined

# %% [markdown]
# ## Dream Samples

# %%
# %matplotlib inline
batch_z = tf.random.normal((1, args.z_size)).numpy()
reconstruct = vae.decode(batch_z)
# show reconstruction
plt.imshow(reconstruct[0])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-13703a05e394> in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 2 batch_z = tf.random.normal((1, args.z_size)).numpy()
#       3 reconstruct = vae.decode(batch_z)
#       4 # show reconstruction
#       5 plt.imshow(reconstruct[0])
#
# NameError: name 'args' is not defined

# %% [markdown]
# ## Driving in true environment
# visualize what the agent sees when driving in the true environment

# %%
c = make_controller(args)
c.load_model('results/{}/{}/log/{}.cma.16.64.json'.format(args.exp_name, args.env_name, args.env_name))
true_env = make_env(args, dream_env=False, with_obs=True)
reconstruct_episode, true_episode, true_r, true_total_r = sim(c, true_env, vae, is_true_env=True, z_size=args.z_size, max_ep_len=args.max_frames)
true_env.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-0c8a17920071> in <module>
# ----> 1 c = make_controller(args)
#       2 c.load_model('results/{}/{}/log/{}.cma.16.64.json'.format(args.exp_name, args.env_name, args.env_name))
#       3 true_env = make_env(args, dream_env=False, with_obs=True)
#       4 reconstruct_episode, true_episode, true_r, true_total_r = sim(c, true_env, vae, is_true_env=True, z_size=args.z_size, max_ep_len=args.max_frames)
#       5 true_env.close()
#
# NameError: name 'make_controller' is not defined

# %%
# %matplotlib notebook
# %matplotlib notebook
# %matplotlib notebook
# %matplotlib notebook
# stupid jupyter bug, just keep copy pasting until it works

import matplotlib.pyplot as plt
import numpy as np
import matplotlib.animation

f = plt.figure()
ax = f.gca()

image = plt.imshow(true_episode[0].numpy(), interpolation='None', animated=True)

def function_for_animation(frame_index):
    image.set_data(reconstruct_episode[frame_index+1].numpy())
    ax.set_title('frame: {}, r: {:.2f}, total reward: {:.2f}'.format(frame_index, true_r[frame_index+1], true_total_r[frame_index+1]))
    return image,

ani = matplotlib.animation.FuncAnimation(f, function_for_animation, interval=40, frames=len(true_episode), blit=True)
# Out:
# <img src="data:image/png;base64,..." width="432">
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-e1bf34c4e819> in <module>
#      12 ax = f.gca()
#      13
# ---> 14 image = plt.imshow(true_episode[0].numpy(), interpolation='None', animated=True)
#      15
#      16 def function_for_animation(frame_index):
#
# NameError: name 'true_episode' is not defined

# %% [markdown]
# ## Return Plot for Controller

# %%
eager_filepath = os.path.join('results/{}/{}/log/{}.cma.16.64.eval_hist.json'.format(args.exp_name, args.env_name, args.env_name))
og_filepath = os.path.join('results/og/log', 'carracing.cma.16.64.hist_best.json')
with open(eager_filepath, 'r') as f:
  eager_data = json.load(f)
with open(og_filepath, 'r') as f:
  og_data = json.load(f)

eager_data = np.array(eager_data)
og_data = np.array(og_data)

eager_comparison_max = eager_data[-1, 0] # b/c we didnt run for 2k
og_max_idx = np.sum(np.array(og_data[: ,0],dtype=np.float) <= eager_comparison_max)
print(og_max_idx)

og_data = np.array(og_data)[:og_max_idx]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-f4cb78736e02> in <module>
# ----> 1 eager_filepath = os.path.join('results/{}/{}/log/{}.cma.16.64.eval_hist.json'.format(args.exp_name, args.env_name, args.env_name))
#       2 og_filepath = os.path.join('results/og/log', 'carracing.cma.16.64.hist_best.json')
#       3 with open(eager_filepath, 'r') as f:
#       4   eager_data = json.load(f)
#       5 with open(og_filepath, 'r') as f:
#
# NameError: name 'args' is not defined

# %%
# %matplotlib inline

eager_x = eager_data[:, 0]
eager_ret = eager_data[:, 1]
eager_std = eager_data[:, 2]

og_x = np.array(og_data[:, 0], dtype=np.float)
og_ret = np.array(og_data[:, 5], dtype=np.float)
# don't have access to standard deviation of the og evaluation

plt.figure()
plt.plot(eager_x, eager_ret)
plt.fill_between(eager_x, eager_ret-eager_std, eager_ret+eager_std, alpha=0.2)
plt.plot(og_x, og_ret)

plt.title('CarRacing-v0')
plt.ylabel('avg. episode reward')
plt.xlabel('generation')
plt.legend(['eager', 'D. Ha original'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-30f86f02ff34> in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
#       2
# ----> 3 eager_x = eager_data[:, 0]
#       4 eager_ret = eager_data[:, 1]
#       5 eager_std = eager_data[:, 2]
#
# NameError: name 'eager_data' is not defined
